# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({'From_To': ['LoNDon_paris', 'MAdrid_miLAN',
'londON_StockhOlm','Budapest_PaRis', 'Brussels_londOn'],
'FlightNumber': [10045, np.nan, 10065, np.nan, 10085],
'RecentDelays': [[23, 47], [], [24, 43, 87], [13], [67, 32]],
'Airline': ['KLM(!)', '<Air France> (12)', '(British Airways. )',
'12. Air France', '"Swiss Air"']})
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 1      MAdrid_miLAN           NaN            []    <Air France> (12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis           NaN          [13]       12. Air France
# 4   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"

# %%
for i in range(0,5):
    if (pd.isnull(df['FlightNumber'].loc[i,])):
        df.loc[i,'FlightNumber']=df.loc[i-1,'FlightNumber']+10
df
# Out:
#    FlightNumber  RecentDelays              Airline
# 0       10045.0      [23, 47]               KLM(!)
# 1       10055.0            []    <Air France> (12)
# 2       10065.0  [24, 43, 87]  (British Airways. )
# 3       10075.0          [13]       12. Air France
# 4       10085.0      [67, 32]          "Swiss Air"

# %%
l=[i.split('_') for i in df['From_To']]
tdf=pd.DataFrame({'From':[l[i][j] for i in range(0,5) for j in range(0,2,2)],
                  'To':[l[i][j] for i in range(0,5) for j in range(1,2,2)]})
tdf
# Out:
#        From         To
# 0    LoNDon      paris
# 1    MAdrid      miLAN
# 2    londON  StockhOlm
# 3  Budapest      PaRis
# 4  Brussels     londOn

# %%
df.drop('From_To',axis=1,inplace=True)

# %%
df
# Out:
#    FlightNumber  RecentDelays              Airline
# 0       10045.0      [23, 47]               KLM(!)
# 1           NaN            []    <Air France> (12)
# 2       10065.0  [24, 43, 87]  (British Airways. )
# 3           NaN          [13]       12. Air France
# 4       10085.0      [67, 32]          "Swiss Air"

# %%
l2=[tdf,df]
df1=pd.concat(l2,axis=1)
df1
# Out:
#        From         To  FlightNumber  RecentDelays              Airline
# 0    LoNDon      paris       10045.0      [23, 47]               KLM(!)
# 1    MAdrid      miLAN           NaN            []    <Air France> (12)
# 2    londON  StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 3  Budapest      PaRis           NaN          [13]       12. Air France
# 4  Brussels     londOn       10085.0      [67, 32]          "Swiss Air"

# %%
 df3 = pd.DataFrame(df1['RecentDelays'].values.tolist(),columns=['Delay1','Delay2','Delay3'])

# %%
df3
# Out:
#    Delay1  Delay2  Delay3
# 0    23.0    47.0     NaN
# 1     NaN     NaN     NaN
# 2    24.0    43.0    87.0
# 3    13.0     NaN     NaN
# 4    67.0    32.0     NaN

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-560180eba35f> in <module>
# ----> 1 pd.isnull(df.FlightNumber.loc[i,])
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1760                 except (KeyError, IndexError, AttributeError):
#    1761                     pass
# -> 1762             return self._getitem_tuple(key)
#    1763         else:
#    1764             # we by definition only have the 0th axis
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1279         # ugly hack for GH #836
#    1280         if self._multi_take_opportunity(tup):
# -> 1281             return self._multi_take(tup)
#    1282
#    1283         # no shortcut needed
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _multi_take(self, tup)
#    1336         # GH 836
# ...
